# %%
history = np.load(open('Fed_Avg_VGG16', 'rb'),allow_pickle=True)
np.array(history_acc).dump(open('swarm_fedprox_acc_random.npy', 'wb'))
np.array(history_loss).dump(open('swarm_fedprox_loss_random.npy', 'wb'))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
swarm_fedprox_acc = np.load(open('swarm_fedprox_acc_random.npy', 'rb'),allow_pickle=True)
swarm_fedprox_loss = np.load(open('swarm_fedprox_loss_random.npy', 'rb'),allow_pickle=True)

swarm_acc = np.load(open('swarm_acc_random.npy', 'rb'),allow_pickle=True)
swarm_loss = np.load(open('swarm_loss_random.npy', 'rb'),allow_pickle=True)

# %%
swarm_fedprox_acc = np.load(open('swarm_fedprox_acc.npy', 'rb'),allow_pickle=True)
swarm_fedprox_loss = np.load(open('swarm_fedprox_loss.npy', 'rb'),allow_pickle=True)

swarm_acc = np.load(open('swarm_acc.npy', 'rb'),allow_pickle=True)
swarm_loss = np.load(open('swarm_loss.npy', 'rb'),allow_pickle=True)

# %%
swarm_fedprox_acc = np.load(open('swarm_fedprox_acc_iid.npy', 'rb'),allow_pickle=True)
swarm_fedprox_loss = np.load(open('swarm_fedprox_loss_iid.npy', 'rb'),allow_pickle=True)

swarm_acc = np.load(open('swarm_acc_iid.npy', 'rb'),allow_pickle=True)
swarm_loss = np.load(open('swarm_loss_iid.npy', 'rb'),allow_pickle=True)

# %%
# for client_0
epoch = 45
plt.plot([i + 1 for i in range(epoch)], [swarm_fedprox_acc[i][0] for i in range(epoch) ], color='b',label= 'Fedprox')
plt.plot([i + 1 for i in range(epoch)], [swarm_acc[i][0] for i in range(epoch) ], color='r', label = 'Average')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Training History : Client 0')
plt.legend()
plt.show()

# %%
# for client_1
epoch= 45
plt.plot([i + 1 for i in range(epoch)], [swarm_fedprox_acc[i][1] for i in range(epoch) ], color='b',label= 'Fedprox')
plt.plot([i + 1 for i in range(epoch)], [swarm_acc[i][1] for i in range(epoch) ], color='r', label = 'Average')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Training History : Client 1')
plt.legend()
plt.show()

# %%
# for client_2
epoch = 45
plt.plot([i + 1 for i in range(epoch)], [swarm_fedprox_acc[i][2] for i in range(epoch) ], color='b',label= 'Fedprox')
plt.plot([i + 1 for i in range(epoch)], [swarm_acc[i][2] for i in range(epoch) ], color='r', label = 'Average')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Training History : Client 2')
plt.legend()
plt.show()

# %%
# for client_3
epoch = 45
plt.plot([i + 1 for i in range(epoch)], [swarm_fedprox_acc[i][3] for i in range(epoch) ], color='b',label= 'Fedprox')
plt.plot([i + 1 for i in range(epoch)], [swarm_acc[i][3] for i in range(epoch) ], color='r', label = 'Average')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Training History : Client 3')
plt.legend()
plt.show()

# %%
# for client_4
epoch = 45
plt.plot([i + 1 for i in range(epoch)], [swarm_fedprox_acc[i][4] for i in range(epoch) ], color='b',label= 'Fedprox')
plt.plot([i + 1 for i in range(epoch)], [swarm_acc[i][4] for i in range(epoch) ], color='r', label = 'Average')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Training History : Client 4')
plt.legend()
plt.show()
